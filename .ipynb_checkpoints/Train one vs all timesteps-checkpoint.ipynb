# %%
# %%time
from syntheticDBN import Bayes_Test
import pandas as pd
import matplotlib.pyplot as plt
import pyAgrum.lib.notebook as gnb
# %matplotlib widget
# Out:
# Wall time: 4.05 s

# %%
# %%time
# Create True DBN
timesteps = 5
nodes = 3
bayestest = Bayes_Test(timesteps=timesteps, nodes=nodes, type='oc_time') 

gnb.show(bayestest.true_dbn)
# Out:
# [1, 5] [25, 1]
# 5 1
# (0, 2)
# (2, 4)
# (4, 6)
# (6, 8)
# (8, 10)
# 5 1
# (1, 3)
# (3, 5)
# (5, 7)
# (7, 9)
# (9, 11)
# 5 1
# (2, 4)
# (4, 6)
# (6, 8)
# (8, 10)
# (10, 12)
# Wall time: 129 ms
