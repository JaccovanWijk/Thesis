# %%
import pandas as pd

# %%
df = pd.read_csv("outputs/fixedscores2.csv",index_col=0)
df
# Out:
#         items  nodes  timesteps  arcs_ratio  islands  values algorithm  \
# 0        1000      4          1    0.999999        1       2        HC
# 1        2000      4          1    0.999999        1       2        HC
# 2        3000      4          1    0.999999        1       2        HC
# 3        4000      4          1    0.999999        1       2        HC
# 4        5000      4          1    0.999999        1       2        HC
# ...       ...    ...        ...         ...      ...     ...       ...
# 105575   6000      6          2    2.000000        1       2     3OFF2
# 105576   7000      6          2    2.000000        1       2     3OFF2
# 105577   8000      6          2    2.000000        1       2     3OFF2
# 105578   9000      6          2    2.000000        1       2     3OFF2
# 105579  10000      6          2    2.000000        1       2     3OFF2
#
#        scorefunction    recall  precision  ...  mean_constraint  \
# ...

# %%
df_hc = df[df["algorithm"]=="HC"]
df_hc
# Out:
#         items  nodes  timesteps  arcs_ratio  islands  values algorithm  \
# 0        1000      4          1    0.999999        1       2        HC
# 1        2000      4          1    0.999999        1       2        HC
# 2        3000      4          1    0.999999        1       2        HC
# 3        4000      4          1    0.999999        1       2        HC
# 4        5000      4          1    0.999999        1       2        HC
# ...       ...    ...        ...         ...      ...     ...       ...
# 102575   6000      6          2    2.000000        1       4        HC
# 102576   7000      6          2    2.000000        1       4        HC
# 102577   8000      6          2    2.000000        1       4        HC
# 102578   9000      6          2    2.000000        1       4        HC
# 102579  10000      6          2    2.000000        1       4        HC
#
#        scorefunction    recall  precision  ...  mean_constraint  \
# ...
